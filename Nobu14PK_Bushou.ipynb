# %% [markdown]
# 信長の野望・創造 Nobunaga no Yabō: Sōzō

# %% [markdown]
# A look into the 2000+ characters, or bushō (武将) in the game.
#
# With the help of N14PK_Browse.exe

# %%
import numpy as np
import pandas as pd
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['All_Bushou.csv']), encoding = 'utf-8')
# Out:
#      <input type="file" id="files-367b4f62-f801-46cf-947a-b2eecf167069" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-367b4f62-f801-46cf-947a-b2eecf167069">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving All_Bushou.csv to All_Bushou.csv

# %%
df.head()
# Out:
#    ID         軍団    名前          城  所在   血族  ...  旗     病死 信仰 出自 士道      アドレス
# 0   0  143966836  蠣崎季広  136252132 NaN    0  ...  0   True  1  0  3  080AB424
# 1   1  143966836  蠣崎慶広  136252132 NaN    0  ...  0   True  1  0  1  080AB594
# 2   2  143966836  蠣崎盛広  136252132 NaN    0  ...  0   True  1  0  1  080AB704
# 3   3  143966836  蠣崎守広  136252132 NaN    0  ...  0  False  1  0  3  080AB874
# 4   4  143966836  近藤義武  136252132 NaN  131  ...  0   True  1  0  0  080AB9E4
#
# [5 rows x 39 columns]

# %%
df = df.set_index(df['ID'])
df = df.drop(columns = ['ID'])
df = df.rename({'軍団': 'Legion', '名前': 'Name', '城': 'City', '所在': 'Whereabout', '血族': 'Bloodline', '一門': 'HasSameBloodline', '実父': 'BiologicalFather', '養父': 'AdoptiveFather', \
                '配偶者': 'Spouse', '身分詳細': 'Title', '城主': 'IsCityCommander', '奉行': 'IsInternalChief', '隠居': 'IsRetired', '女性': 'IsFemale', '傷病': 'IsWoundedOrSick', '年齢': 'Age', \
                '余命': 'YearsTillDeath', '仕官': 'YearsSinceEmployed', '格': 'Rank', '統率': 'Command', '武勇': 'Valor', '知略': 'Resourcefulness', '政治': 'Governing', '戦法': 'BattleMove', \
                '特性': 'Skills', '成長型': 'SkillTrack', '主義(創造)': 'Ideology', '忠計': 'AllegianceAddOn', '必忠': 'AllegianceNeeded', '叛心': 'Betrayal', '登場国': 'PlaceOfOrigin', \
                '馬印': 'HorseInsignia', '旗': 'Flag', '病死': 'DiedInDisease', '信仰': 'Faith', '出自': 'ClassOfOrigin', '士道': 'PathOfBushidou', 'アドレス': 'Address'}, axis = 1)

# %%
df['Overall'] = df['Command'] + df['Valor'] + df['Resourcefulness'] + df['Governing']
df['Creativeness'] = df['Ideology'].str.extract('(\d+)').astype(int)
df.head()
# Out:
#        Legion  Name       City  ...   Address  Overall  Creativeness
# ID                              ...
# 0   143966836  蠣崎季広  136252132  ...  080AB424      273            50
# 1   143966836  蠣崎慶広  136252132  ...  080AB594      276            50
# 2   143966836  蠣崎盛広  136252132  ...  080AB704      201            70
# 3   143966836  蠣崎守広  136252132  ...  080AB874      202            60
# 4   143966836  近藤義武  136252132  ...  080AB9E4      250            50
#
# [5 rows x 40 columns]

# %% [markdown]
# Remove those that are not "bushou proper" in the game

# %%
df.groupby('Title').size()
# Out:
# Title
# 他         258
# 国人衆       166
# 大名         76
# 家臣       1718
# 家臣(姫)      13
# 浪人         21
# dtype: int64

# %%
df1 = df.loc[~df['Title'].isin(['他', '国人衆']), :].copy()
df1.shape
# Out:
# (1828, 40)

# %%
df1['IdInClan'] = df1.groupby('Bloodline')['Overall'].rank(method="first", ascending=False).astype(int)

# %% [markdown]
# Top 10 bushou (武将), based on overall abilities

# %%
df1.sort_values(by = ['Overall', 'Command'], ascending=False)[:10]
# Out:
#          Legion  Name       City  ...  Overall  Creativeness  IdInClan
# ID                                ...
# 338   143973940  織田信長  137537332  ...      380           100         1
# 453   143974828  武田信玄  136466332  ...      379            25         1
# 770   143981636  毛利元就  136882832  ...      373             5         1
# 252   143973348  北条氏康  136454432  ...      370            50         1
# 298   143973052  徳川家康  136621032  ...      369            55         1
# 362   143967724  羽柴秀吉  136775732  ...      368            90         1
# 123   143971276  伊達政宗  136299732  ...      364           100         1
# 416   143968316  明智光秀  136704332  ...      364            55         1
# 1393  143973348  北条氏綱  136454432  ...      361            50         2
# 479   143980748  真田昌幸  137489732  ...      360            30         1
#
# [10 rows x 41 columns]

# %%
import matplotlib.pyplot as plt
df1['Valor'].plot(y = 'Valor', kind='hist', bins = 20, rwidth = 0.8)
plt.xlabel('Valor')
plt.show()

# %% [markdown]
# Ideology (creativeness) ranges from 0 to 100

# %%
df1['Creativeness'].plot(y = 'Creativeness', kind='hist', bins = 20, rwidth = 0.8)
plt.xlabel('Creativeness')
plt.title('Ideology (< 40: Conservative; >= 70: Creative )')
plt.xticks(range(0, 110, 10))
plt.show()

# %% [markdown]
# People with the same Bloodline are in a clan. Find the largest clans.

# %%
clans = df1.groupby('Bloodline').size()
df1["ClanSize"] = df["Bloodline"].map(clans)
df1.loc[(df1['ClanSize']>= 8) & (df1['IdInClan'] == 1), ['Name', 'Bloodline', 'IdInClan', 'ClanSize']].sort_values(by='ClanSize', ascending=False)
# Out:
#         Name  Bloodline  IdInClan  ClanSize
# ID
# 338     織田信長         44         1      18.0
# 123     伊達政宗         21         1      17.0
# 656     三好長慶         80         1      14.0
# 252     北条氏康         40         1      13.0
# 479     真田昌幸         54         1      13.0
# 967     島津義弘        124         1      13.0
# 298     徳川家康         42         1      12.0
# 453     武田信玄         53         1      12.0
# 770     毛利元就         98         1      12.0
# 144     佐竹義重         22         1      11.0
# 1793   龍造寺家兼        114         1      10.0
# 834   長宗我部元親        106         1      10.0
# 274     今川義元         41         1       9.0
# 995     南部安信          1         1       8.0
# 1666    尼子経久         87         1       8.0
# 1645    筒井順昭         83         1       8.0
# 89      安東愛季         16         1       8.0
# 990     蠣崎義広          0         1       8.0
# 919     有馬晴純        117         1       8.0
# 109     最上義光         20         1       8.0
# 625     細川幽斎         79         1       8.0
# 1810    相良義滋        121         1       8.0
